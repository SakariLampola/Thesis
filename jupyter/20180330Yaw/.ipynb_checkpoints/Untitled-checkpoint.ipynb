# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
import cv2
data = pd.read_csv('Camera.txt')
data.shape
# Out:
# (443, 6)

# %%
data["yaw"].plot()
data["yaw_estimated"].plot()

# %%
data["x"].plot()
data["y"].plot()
data["z"].plot()
