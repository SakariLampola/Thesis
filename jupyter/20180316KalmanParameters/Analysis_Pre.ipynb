# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)

# %%
data = pd.read_csv('Pattern_Pre.txt')
data.shape
# Out:
# (154, 45)

# %%
data.head()
# Out:
#    time             id  class_id  confidence     x_min     x_max    y_min  \
# 0   0.0  1949838578464         2         1.0  1114.000  1166.000  201.000
# 1   0.0  1947924783960         2         1.0  1072.000  1129.000  200.000
# 2   0.1  1949838578464         2         1.0  1106.799  1161.799  205.801
# 3   0.1  1947924783960         2         1.0  1064.799  1128.400  203.600
# 4   0.2  1949838578464         2         1.0  1097.749  1157.833  208.334
#
#      y_max  border_left  border_right   ...     vy_center  vx_center_var  \
# 0  359.000            1             1   ...         0.000        400.000
# 1  363.000            1             1   ...         0.000        400.000
# 2  346.398            1             1   ...       -12.997        240.032
# 3  363.600            1             1   ...         6.999        240.032
# 4  354.918            1             1   ...        16.248        233.373
#
#    vy_center_var  retention_count           body  matched  x_min_d  x_max_d  \
# 0        400.000                0  1947924784128    False   1114.0   1166.0
# 1        400.000                0  1947924784128    False   1072.0   1129.0
# 2        240.032                0  1947924784128     True   1102.0   1159.0
# 3        240.032                0  1947924784128     True   1060.0   1128.0
# 4        233.373                0  1947924784128     True   1093.0   1156.0
#
#    y_min_d  y_max_d
# 0    201.0    359.0
# 1    200.0    363.0
# 2    209.0    338.0
# 3    206.0    364.0
# 4    209.0    364.0
#
# [5 rows x 45 columns]

# %%
data_left = data[(data.id==1949838578464)]
data_right = data[(data.id==1947924783960)]

# %%
data_left.shape
# Out:
# (77, 45)

# %%
data_left['x_min_d'].plot()
data_left['x_min'].plot()
data_left['x_max_d'].plot() 
data_left['x_max'].plot()
data_left['y_min_d'].plot()
data_left['y_min'].plot()
data_left['y_max_d'].plot() 
data_left['y_max'].plot()
plt.legend()

# %%
data_right['x_min_d'].plot()
data_right['x_min'].plot()
data_right['x_max_d'].plot() 
data_right['x_max'].plot()
data_right['y_min_d'].plot()
data_right['y_min'].plot()
data_right['y_max_d'].plot() 
data_right['y_max'].plot()
plt.legend()

# %%
data_left['vx_min'].plot()
data_left['vx_max'].plot() 
data_left['vy_min'].plot()
data_left['vy_max'].plot() 
plt.legend()

# %%
data_body = pd.read_csv('Body_Pre.txt')
data_body.shape
# Out:
# (77, 101)

# %%
data_body.head()
# Out:
#    time             id  class_id      x      y      z     vx     vy     vz  \
# 0   0.0  1947924784128         2  6.071 -0.328 -8.822  0.000  0.000  0.000
# 1   0.1  1947924784128         2  6.428 -0.259 -9.545  0.035  0.007 -0.072
# 2   0.2  1947924784128         2  6.508 -0.435 -9.779  0.665 -1.458 -1.961
# 3   0.3  1947924784128         2  5.578 -0.475 -8.503 -5.076 -0.848  6.517
# 4   0.4  1947924784128         2  5.061 -0.270 -7.897 -5.114  0.374  6.325
#
#      sigma_00     ...       c_sigma_52  c_sigma_53  c_sigma_54  c_sigma_55  \
# 0  100000.000     ...            0.000         0.0         0.0       0.000
# 1     199.605     ...         1009.881         0.0         0.0   99011.858
# 2     171.299     ...         1707.601         0.0         0.0   28389.109
# 3     157.444     ...        11867.178         0.0         0.0    9057.993
# 4     136.450     ...         4988.495         0.0         0.0    3836.935
#
#    distance_stereo  distance_size  distance  x_projected  y_projected  \
# 0           10.714          7.888    10.714        6.071       -0.328
# 1           11.512          9.237    11.512        6.429       -0.259
# 2           11.794          7.758    11.794        6.520       -0.464
# 3            9.699          6.856     9.699        5.308       -0.446
# 4            9.396         10.426     9.396        5.057       -0.135
#
#    z_projected
# 0       -8.822
# 1       -9.546
# 2       -9.817
# 3       -8.106
# 4       -7.918
#
# [5 rows x 101 columns]

# %%
data_body['x'].plot()
data_body['x_projected'].plot()
data_body['y'].plot()
data_body['y_projected'].plot()
data_body['z'].plot()
data_body['z_projected'].plot()
plt.legend()

# %%
data_body['vx'].plot()
data_body['vy'].plot()
data_body['vz'].plot()
plt.legend()
