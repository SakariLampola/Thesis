# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)

# %%
data = pd.read_csv('Pattern_Post.txt')
data.shape
# Out:
# (154, 45)

# %%
data.head()
# Out:
#    time             id  class_id  confidence    x_min     x_max    y_min  \
# 0   0.0  1947932955704         2         1.0  1114.00  1166.000  201.000
# 1   0.0  1947932955144         2         1.0  1072.00  1129.000  200.000
# 2   0.1  1947932955704         2         1.0  1106.00  1161.333  206.333
# 3   0.1  1947932955144         2         1.0  1064.00  1128.333  204.000
# 4   0.2  1947932955704         2         1.0  1095.99  1156.997  209.000
#
#      y_max  border_left  border_right   ...     vy_center  vx_center_var  \
# 0  359.000            1             1   ...         0.000        200.000
# 1  363.000            1             1   ...         0.000        200.000
# 2  345.000            1             1   ...       -21.667        133.333
# 3  363.667            1             1   ...        11.667        133.333
# 4  355.362            1             1   ...        21.955        133.555
#
#    vy_center_var  retention_count           body  matched  x_min_d  x_max_d  \
# ...

# %%
data_left = data[(data.id==1947932955704)]
data_right = data[(data.id==1947932955144)]

# %%
data_left.shape
# Out:
# (77, 45)

# %%
data_left['x_min_d'].plot()
data_left['x_min'].plot()
data_left['x_max_d'].plot() 
data_left['x_max'].plot()
data_left['y_min_d'].plot()
data_left['y_min'].plot()
data_left['y_max_d'].plot() 
data_left['y_max'].plot()
plt.legend()

# %%
data_right['x_min_d'].plot()
data_right['x_min'].plot()
data_right['x_max_d'].plot() 
data_right['x_max'].plot()
data_right['y_min_d'].plot()
data_right['y_min'].plot()
data_right['y_max_d'].plot() 
data_right['y_max'].plot()
plt.legend()

# %%
data_left['vx_min'].plot()
data_left['vx_max'].plot() 
data_left['vy_min'].plot()
data_left['vy_max'].plot() 
plt.legend()

# %%
data_body = pd.read_csv('Body_Post.txt')
data_body.shape
# Out:
# (77, 101)

# %%
data_body.head()
# Out:
#    time             id  class_id      x      y      z     vx     vy     vz  \
# 0   0.0  1947932957552         2  6.071 -0.328 -8.822  0.000  0.000  0.000
# 1   0.1  1947932957552         2  6.181 -0.306 -9.043  0.099  0.019 -0.201
# 2   0.2  1947932957552         2  6.285 -0.354 -9.279  0.257 -0.054 -0.562
# 3   0.3  1947932957552         2  6.016 -0.388 -8.973 -0.334 -0.101  0.169
# 4   0.4  1947932957552         2  5.698 -0.309 -8.636 -0.910  0.049  0.825
#
#    sigma_00     ...       c_sigma_52  c_sigma_53  c_sigma_54  c_sigma_55  \
# 0    10.000     ...            0.000         0.0         0.0       0.000
# 1     7.639     ...            7.927         0.0         0.0      99.222
# 2     7.143     ...           12.885         0.0         0.0      92.192
# 3     7.355     ...         1654.810         0.0         0.0     578.645
# 4     7.674     ...         1588.719         0.0         0.0     565.215
#
#    distance_stereo  distance_size  distance  x_projected  y_projected  \
# ...

# %%
data_body['x'].plot()
data_body['x_projected'].plot()
data_body['y'].plot()
data_body['y_projected'].plot()
data_body['z'].plot()
data_body['z_projected'].plot()
plt.legend()

# %%
data_body['vx'].plot()
data_body['vy'].plot()
data_body['vz'].plot()
plt.legend()
