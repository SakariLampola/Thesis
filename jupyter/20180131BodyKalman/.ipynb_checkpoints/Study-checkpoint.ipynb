# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv('../../Body.txt')
data.shape
# Out:
# (901, 98)

# %%
data_one = data[(data.id==1922736835664) & (data.z_pattern!=0)]
data_one = data_one.set_index('time')

# %%
data_one.shape
# Out:
# (901, 97)

# %%
data_one.head()
# Out:
#                   id  class_id      x      y       z     vx     vy     vz  \
# time
# 0.000  1922736835664         4  1.119  3.660 -60.000  0.000  0.000  0.000
# 0.033  1922736835664         4  1.118  3.639 -59.843 -0.005 -0.083  0.613
# 0.067  1922736835664         4  1.123  3.628 -59.926  0.027 -0.129  0.035
# 0.100  1922736835664         4  1.133  3.612 -59.868  0.082 -0.202  0.387
# 0.133  1922736835664         4  1.146  3.605 -59.845  0.146 -0.206  0.450
#
#           ax     ay    ...     sigma_84  sigma_85  sigma_86  sigma_87  \
# time                   ...
# 0.000  0.000  0.000    ...          0.0   333.667       0.0       0.0
# 0.033 -0.000 -0.002    ...          0.0   650.606       0.0       0.0
# 0.067  0.001 -0.004    ...          0.0   928.125       0.0       0.0
# 0.100  0.006 -0.010    ...          0.0  1154.569       0.0       0.0
# 0.133  0.012 -0.010    ...          0.0  1335.661       0.0       0.0
#
#         sigma_88  x_pattern  y_pattern  z_pattern        pattern    status
# time
# 0.000  10000.100      1.119      3.660    -60.000  1922736835608  measured
# 0.033   9999.818      1.116      3.604    -59.592  1922736835608  measured
# 0.067   9997.259      1.134      3.613    -60.117  1922736835608  measured
# 0.100   9989.293      1.150      3.590    -59.762  1922736835608  measured
# 0.133   9972.840      1.165      3.603    -59.826  1922736835608  measured
#
# [5 rows x 97 columns]

# %%
data_one.tail()
# Out:
#                    id  class_id      x      y       z     vx     vy     vz  \
# time
# 29.897  1922736835664         4  8.745  3.459 -56.087  0.511  0.221 -2.677
# 29.930  1922736835664         4  8.768  3.468 -56.194  0.521  0.225 -2.729
# 29.963  1922736835664         4  8.790  3.478 -56.301  0.530  0.230 -2.779
# 29.997  1922736835664         4  8.812  3.487 -56.402  0.538  0.234 -2.823
# 30.030  1922736835664         4  8.832  3.496 -56.498  0.545  0.238 -2.861
#
#            ax     ay    ...     sigma_84  sigma_85  sigma_86  sigma_87  \
# time                    ...
# 29.897  0.136  0.084    ...          0.0    12.923       0.0       0.0
# 29.930  0.138  0.084    ...          0.0    12.929       0.0       0.0
# 29.963  0.139  0.085    ...          0.0    12.925       0.0       0.0
# 29.997  0.141  0.086    ...          0.0    12.911       0.0       0.0
# 30.030  0.142  0.086    ...          0.0    12.887       0.0       0.0
#
#         sigma_88  x_pattern  y_pattern  z_pattern        pattern    status
# time
# 29.897     9.621      8.816      3.485    -56.345  1922736835608  measured
# 29.930     9.607      8.838      3.494    -56.430  1922736835608  measured
# 29.963     9.589      8.857      3.505    -56.510  1922736835608  measured
# 29.997     9.568      8.866      3.511    -56.522  1922736835608  measured
# 30.030     9.542      8.866      3.511    -56.522  1922736835608  measured
#
# [5 rows x 97 columns]

# %%
data_one['x'].plot()
data_one['x_pattern'].plot()

# %%
data_one['y'].plot()
data_one['y_pattern'].plot()

# %%
data_one['z'].plot()
data_one['z_pattern'].plot()

# %%
data_one['vx'].plot()
data_one['vy'].plot()
data_one['vz'].plot()

# %%
data_one['ax'].plot()
data_one['ay'].plot()
data_one['az'].plot()
