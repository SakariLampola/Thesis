# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv('ImageObjectKalmanFilteringTraceCalfTest.txt')

# %%
example = data.loc[data['id']==1]
print(example.shape)
# Out:
# (161, 40)

# %%
example.head()
# Out:
#     time  id  x_min_p  x_max_p  y_min_p  y_max_p  x_min_m  x_max_m  y_min_m  \
# 0  0.033   1  452.000  834.000   70.000  650.000    452.0    834.0     70.0
# 1  0.067   1  452.000  834.000   70.000  650.000    451.0    837.0     68.0
# 2  0.100   1  450.977  837.069   67.954  654.092    453.0    834.0     64.0
# 3  0.133   1  452.418  835.432   63.676  655.489    453.0    826.0     66.0
# 4  0.167   1  453.176  828.147   63.642  655.548    453.0    830.0     65.0
#
#    y_max_m     ...      do_c8  io_c1  io_c2  io_c3  io_c4  io_c5  io_c6  \
# 0    650.0     ...       0.15   0.27   0.42   0.06    0.0   0.01   0.04
# 1    654.0     ...       0.15   0.27   0.42   0.06    0.0   0.01   0.04
# 2    654.0     ...       0.15   0.27   0.42   0.06    0.0   0.01   0.04
# 3    654.0     ...       0.16   0.27   0.42   0.06    0.0   0.01   0.04
# 4    655.0     ...       0.15   0.27   0.42   0.06    0.0   0.01   0.04
#
#    io_c7  io_c8  confidence
# 0   0.04   0.15        0.97
# ...

# %%
example['y_max_m'].plot()
example['y_max_p'].plot()
example['y_max_c'].plot()

# %%
example['vy_max_p'].plot()
example['vy_max_c'].plot()

# %%
example['confidence'].plot()
