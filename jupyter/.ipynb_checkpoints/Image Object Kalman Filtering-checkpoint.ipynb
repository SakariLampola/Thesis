# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

data = pd.read_csv('ImageObjectKalmanFilteringTraceCar.txt')
td = 1.0/25.0
blue_car = data.loc[data['id']==116]
blue_car.head()
# Out:
#        time   id  x_min_p  x_max_p  y_min_p  y_max_p  x_min_m  x_max_m  \
# 1568  21.56  116    428.0    551.0    182.0    247.0    428.0    556.0
# 1571  21.60  116    428.0    556.0    178.0    250.0    433.0    558.0
# 1574  21.64  116    433.0    558.0    183.0    249.0    437.0    560.0
# 1577  21.68  116    437.0    560.0    185.0    248.0    438.0    563.0
# 1580  21.72  116    438.0    563.0    185.0    252.0    444.0    566.0
#
#       y_min_m  y_max_m  ...    do_c7  do_c8  io_c1  io_c2  io_c3  io_c4  \
# 1568    178.0    250.0  ...     0.06   0.03   0.22   0.03   0.01   0.01
# 1571    183.0    249.0  ...     0.05   0.04   0.22   0.03   0.01   0.01
# 1574    185.0    248.0  ...     0.06   0.03   0.22   0.03   0.01   0.01
# 1577    185.0    252.0  ...     0.06   0.04   0.22   0.03   0.01   0.01
# 1580    178.0    251.0  ...     0.06   0.03   0.22   0.03   0.01   0.01
#
#       io_c5  io_c6  io_c7  io_c8
# 1568   0.13    0.5   0.07   0.03
# 1571   0.13    0.5   0.07   0.03
# 1574   0.13    0.5   0.07   0.03
# 1577   0.13    0.5   0.07   0.03
# 1580   0.13    0.5   0.07   0.03
#
# [5 rows x 31 columns]

# %%
blue_car.shape
# Out:
# (156, 31)

# %%
x_min = pd.DataFrame({'time': blue_car['time'], 'l' : blue_car['x_min_m']})
x_min.index = x_min['time']
del x_min['time']
x_min.head()
# Out:
#            l
# time
# 21.56  428.0
# 21.60  433.0
# 21.64  437.0
# 21.68  438.0
# 21.72  444.0

# %%
x_min.plot()

# %%
x_min_diff = x_min.diff(1)
x_min_diff = x_min_diff.dropna()
x_min_diff.plot()

# %%
x_min_diff_diff = x_min_diff.diff(1)
x_min_diff_diff = x_min_diff_diff.dropna()
x_min_diff_diff.plot()

# %%
x_min_var = x_min.var()
x_min_diff_var = x_min_diff.var()
x_min_diff_diff_var = x_min_diff_diff.var()
print(x_min_var)
print(x_min_diff_var)
print(x_min_diff_diff_var)
# Out:
# l    39644.218693
# dtype: float64
# l    38.446167
# dtype: float64
# l    80.447543
# dtype: float64

# %%
R = np.array([[1.0, 0.0],[0.0, 1.0]]) # state equation variances
Q = np.array([38.0]) # measurent variance
A = np.array([[1.0, td],[0.0, 1.0]]) # state equation matrix
C = np.array([[1.0, 0.0]]) # measurement matrix
print(R)
print(Q)
print(A)
print(C)
# Out:
# [[ 1.  0.]
#  [ 0.  1.]]
# [ 38.]
# [[ 1.    0.04]
#  [ 0.    1.  ]]
# [[ 1.  0.]]

# %%
length,width = x_min.shape
print(length)
mu = np.array([[x_min['l'].iloc[0]],[0.0]])
print(mu)
sigma = np.array([[1.0, 0],[0.0, 1.0]])
print(sigma)
x_min_m = np.array([x_min['l'].iloc[0]])
x_min_f = np.array([x_min['l'].iloc[0]])
vx_min_f = np.array([0.0])
x_min_error_prev = np.zeros((length-1,1))
x_min_error_filter = np.zeros((length-1,1))
# Out:
# 156
# [[ 428.]
#  [   0.]]
# [[ 1.  0.]
#  [ 0.  1.]]

# %%
for i in range(0, length):
    mu = A.dot(mu)
    if i > 0:
        x_min_error_prev[i-1] =  abs(x_min['l'].iloc[i-1] - x_min['l'].iloc[i])
        x_min_error_filter[i-1] = abs(mu[0] - x_min['l'].iloc[i])
    sigma = A.dot(sigma).dot(A.T) + R
    K = sigma.dot(C.T).dot(np.linalg.inv(C.dot(sigma).dot(C.T) + Q))
    mu = mu + K.dot(x_min['l'].iloc[i]-C.dot(mu))
    sigma = (np.eye(2)-K.dot(C)).dot(sigma)
    x_min_m = np.vstack((x_min_m, [x_min['l'].iloc[i]]))
    x_min_f = np.vstack((x_min_f, mu[0]))
    vx_min_f = np.vstack((vx_min_f, mu[1]))

# %%
print(x_min_m.shape)
print(x_min_f.shape)
print(vx_min_f.shape)
print(x_min_error_prev[0:3])
print(x_min_error_filter[0:3])
# Out:
# (157, 1)
# (157, 1)
# (157, 1)
# [[ 5.]
#  [ 4.]
#  [ 1.]]
# [[ 5.        ]
#  [ 8.64402731]
#  [ 8.87181887]]

# %%
plt.plot(x_min_m)
plt.plot(x_min_f)

# %%
plt.plot(vx_min_f)

# %%
plt.hist(x_min_error_prev)
print(np.mean(x_min_error_prev))
# Out:
# 5.32903225806

# %%
plt.hist(x_min_error_filter)
print(np.mean(x_min_error_filter))
# Out:
# 9.44186196322

# %%
data = pd.read_csv('ImageObjectKalmanFilteringTraceCalf.txt')
td = 1.0/29.97
calf = data.loc[data['id']==1]
calf.head()
# Out:
#     time  id  x_min_p  x_max_p  y_min_p  y_max_p  x_min_m  x_max_m  y_min_m  \
# 0  0.033   1    452.0    834.0     70.0    650.0    452.0    834.0     70.0
# 1  0.067   1    452.0    834.0     70.0    650.0    451.0    837.0     68.0
# 2  0.100   1    451.0    837.0     68.0    654.0    453.0    834.0     64.0
# 3  0.133   1    453.0    834.0     64.0    654.0    453.0    826.0     66.0
# 4  0.167   1    453.0    826.0     66.0    654.0    453.0    830.0     65.0
#
#    y_max_m  ...    do_c7  do_c8  io_c1  io_c2  io_c3  io_c4  io_c5  io_c6  \
# 0    650.0  ...     0.04   0.15   0.27   0.42   0.06    0.0   0.01   0.04
# 1    654.0  ...     0.04   0.15   0.27   0.42   0.06    0.0   0.01   0.04
# 2    654.0  ...     0.04   0.15   0.27   0.42   0.06    0.0   0.01   0.04
# 3    654.0  ...     0.05   0.16   0.27   0.42   0.06    0.0   0.01   0.04
# 4    655.0  ...     0.04   0.15   0.27   0.42   0.06    0.0   0.01   0.04
#
#    io_c7  io_c8
# 0   0.04   0.15
# 1   0.04   0.15
# 2   0.04   0.15
# 3   0.04   0.15
# 4   0.04   0.15
#
# [5 rows x 31 columns]

# %%
calf.shape
# Out:
# (161, 31)

# %%
x_min = pd.DataFrame({'time': calf['time'], 'l' : calf['x_min_m']})
x_min.index = x_min['time']
del x_min['time']
x_min.head()
# Out:
#            l
# time
# 0.033  452.0
# 0.067  451.0
# 0.100  453.0
# 0.133  453.0
# 0.167  453.0

# %%
x_min.plot()

# %%
x_min_diff = x_min.diff(1)
x_min_diff = x_min_diff.dropna()
x_min_diff.plot()

# %%
x_min_diff_diff = x_min_diff.diff(1)
x_min_diff_diff = x_min_diff_diff.dropna()
x_min_diff_diff.plot()

# %%
x_min_var = x_min.var()
x_min_diff_var = x_min_diff.var()
x_min_diff_diff_var = x_min_diff_diff.var()
print(x_min_var)
print(x_min_diff_var)
print(x_min_diff_diff_var)
# Out:
# l    595.999379
# dtype: float64
# l    16.645873
# dtype: float64
# l    32.865138
# dtype: float64

# %%
R = np.array([[1.0, 0.0],[0.0, 1.0]]) # state equation variances
Q = np.array([16.0]) # measurent variance
A = np.array([[1.0, td],[0.0, 1.0]]) # state equation matrix
C = np.array([[1.0, 0.0]]) # measurement matrix
print(R)
print(Q)
print(A)
print(C)
# Out:
# [[ 1.  0.]
#  [ 0.  1.]]
# [ 16.]
# [[ 1.         0.0333667]
#  [ 0.         1.       ]]
# [[ 1.  0.]]

# %%
length,width = x_min.shape
print(length)
mu = np.array([[x_min['l'].iloc[0]],[0.0]])
print(mu)
sigma = np.array([[1.0, 0],[0.0, 1.0]])
print(sigma)
x_min_m = np.array([x_min['l'].iloc[0]])
x_min_f = np.array([x_min['l'].iloc[0]])
vx_min_f = np.array([0.0])
x_min_error_prev = np.zeros((length-1,1))
x_min_error_filter = np.zeros((length-1,1))
# Out:
# 161
# [[ 452.]
#  [   0.]]
# [[ 1.  0.]
#  [ 0.  1.]]

# %%
for i in range(0, length):
    mu = A.dot(mu)
    if i > 0:
        x_min_error_prev[i-1] =  abs(x_min['l'].iloc[i-1] - x_min['l'].iloc[i])
        x_min_error_filter[i-1] = abs(mu[0] - x_min['l'].iloc[i])
    sigma = A.dot(sigma).dot(A.T) + R
    K = sigma.dot(C.T).dot(np.linalg.inv(C.dot(sigma).dot(C.T) + Q))
    mu = mu + K.dot(x_min['l'].iloc[i]-C.dot(mu))
    sigma = (np.eye(2)-K.dot(C)).dot(sigma)
    x_min_m = np.vstack((x_min_m, [x_min['l'].iloc[i]]))
    x_min_f = np.vstack((x_min_f, mu[0]))
    vx_min_f = np.vstack((vx_min_f, mu[1]))

# %%
print(x_min_m.shape)
print(x_min_f.shape)
print(vx_min_f.shape)
print(x_min_error_prev[0:3])
print(x_min_error_filter[0:3])
# Out:
# (162, 1)
# (162, 1)
# (162, 1)
# [[ 1.]
#  [ 2.]
#  [ 0.]]
# [[ 1.        ]
#  [ 1.14833092]
#  [ 0.94789607]]

# %%
plt.plot(x_min_m)
plt.plot(x_min_f)

# %%
plt.plot(vx_min_f)

# %%
plt.hist(x_min_error_prev)
print(np.mean(x_min_error_prev))
# Out:
# 2.86875

# %%
plt.hist(x_min_error_filter)
print(np.mean(x_min_error_filter))
# Out:
# 5.00584318437
