# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv('BodyBoat.txt')
data.shape
# Out:
# (901, 51)

# %%
data_one = data[(data.id==2059439127856) ]
data_one = data_one.set_index('time')
data_one.shape
# Out:
# (901, 50)

# %%
data_one.head()
# Out:
#                   id  class_id      x      y       z     vx     vy     vz  \
# time
# 0.000  2059439127856         4  1.031  3.371 -82.890  0.000  0.000  0.000
# 0.033  2059439127856         4  1.030  3.345 -82.669 -0.004 -0.281  2.376
# 0.067  2059439127856         4  1.040  3.334 -82.947  0.120 -0.302 -2.359
# 0.100  2059439127856         4  1.056  3.323 -82.996  0.257 -0.308 -2.017
# 0.133  2059439127856         4  1.070  3.319 -82.918  0.313 -0.248 -0.650
#
#        sigma_00  sigma_01     ...       sigma_52  sigma_53  sigma_54  \
# time                          ...
# 0.000   199.601       0.0     ...          6.653       0.0       0.0
# 0.033   121.761       0.0     ...       1306.438       0.0       0.0
# 0.067   119.333       0.0     ...       1577.645       0.0       0.0
# 0.100   116.175       0.0     ...       1321.579       0.0       0.0
# 0.133   107.779       0.0     ...       1015.304       0.0       0.0
#
#         sigma_55  x_pattern  y_pattern  z_pattern        pattern  status  \
# time
# 0.000  99889.012      1.031      3.371    -82.890  2059439127800       1
# 0.033  78074.001      1.030      3.328    -82.526  2059439127800       1
# 0.067  47219.151      1.046      3.333    -83.190  2059439127800       1
# 0.100  26383.199      1.064      3.323    -82.974  2059439127800       1
# 0.133  15205.221      1.075      3.325    -82.794  2059439127800       1
#
#        collision_p
# time
# 0.000          0.0
# 0.033          0.0
# 0.067          0.0
# 0.100          0.0
# 0.133          0.0
#
# [5 rows x 50 columns]

# %%
data_one['status'].plot()

# %%
data_one['x_pattern'].plot() # blue, measurement
data_one['x'].plot() # green, filtered + predicted

# %%
data_one['y_pattern'].plot() # blue, measurement
data_one['y'].plot() # green, filtered + predicted

# %%
data_one['z_pattern'].plot() # blue, measurement
data_one['z'].plot() # green, filtered + predicted

# %%
data_one['vx'].plot() # blue
data_one['vy'].plot() # green
data_one['vz'].plot() # red

# %%
data_one['sigma_00'].plot() # blue, x location variance
data_one['sigma_33'].plot() # green, x velocity variance
