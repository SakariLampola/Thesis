# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv('Pattern.txt')
data.shape
# Out:
# (3508, 45)

# %%
data_one = data[(data.id==2061577776432) ]
data_one = data_one.set_index('time')
data_one.shape
# Out:
# (116, 44)

# %%
data_one.head()
# Out:
#                  id  class_id  confidence    x_min    x_max    y_min    y_max  \
# time
# 4.48  2061577776432         7       0.812  369.000  519.000  185.000  304.000
# 4.52  2061577776432         7       0.624  366.403  519.519  183.442  306.077
# 4.56  2061577776432         7       0.771  365.724  521.346  182.793  308.151
# 4.60  2061577776432         7       0.701  363.384  523.702  184.258  308.772
# 4.64  2061577776432         7       0.646  360.887  526.958  187.670  309.934
#
#       border_left  border_right  border_top   ...     vy_center  \
# time                                          ...
# 4.48            1             1           1   ...         0.000
# 4.52            1             1           1   ...         0.481
# 4.56            1             1           1   ...         3.447
# 4.60            1             1           1   ...         8.567
# 4.64            1             1           1   ...        19.988
#
# ...

# %%
data_one['matched'].plot()

# %%
data_one['x_min_d'].plot() # blue, measurement
data_one['x_min'].plot() # green, filtered + predicted

# %%
data_one['vx_min'].plot()

# %%
data_one['sigma_x_min_00'].plot()

# %%
data_one['sigma_x_min_01'].plot()

# %%
data_one['sigma_x_min_10'].plot()

# %%
data_one['sigma_x_min_11'].plot()

# %%
data_one['confidence'].plot()
