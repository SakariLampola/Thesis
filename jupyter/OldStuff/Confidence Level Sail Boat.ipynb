# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv('ConfidenceLevelSailBoatTrace.txt')

# %%
data['confidence'].plot()

# %%
dataCars = pd.read_csv('ConfidenceLevelCarTrace.txt')

# %%
example = dataCars.loc[dataCars['id']==4]

# %%
example['confidence'].plot()

# %%
dataCalf = pd.read_csv('ConfidenceLevelCalfTrace.txt')

# %%
example = dataCars.loc[dataCars['id']==1]

# %%
example['confidence'].plot()
